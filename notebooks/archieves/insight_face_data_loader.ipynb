# %% [raw]
# ## Calculating Embeddings from folder

# %%
# 📦 Imports for training & saving embeddings
import os
import cv2
import numpy as np
import pickle
from insightface.app import FaceAnalysis

# 🚀 Initialize InsightFace model
model = FaceAnalysis(name='buffalo_l')
model.prepare(ctx_id=0, det_thresh=0.1, det_size=(160, 160))  # Use -1 for CPU

# 📁 Directory with labeled training images
training_path = '../Ilhan'
known_embeddings = []

classNames = []

os.makedirs('training_images', exist_ok=True)

# 📌 Process each image
for file in os.listdir(training_path):
    img_path = os.path.join(training_path, file)
    img = cv2.imread(img_path)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    faces = model.get(img_rgb)

    if faces:
        emb = faces[0].embedding
        x1, y1, x2, y2 = faces[0].bbox.astype(int)

        cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)


        name = os.path.splitext(file)[0]
        print(f"Processing {name}...")
        # Save the cropped face image
        # if face_crop.size > 0:
        #  cv2.imwrite(f"training_images/cropped_{name}", face_crop)

        known_embeddings.append(emb)
        
        print(f"✅ Detected {name} in {file}")
        classNames.append(name)

        # cv2.imshow(f"Detected", img)
        # cv2.waitKey(0)

    else:
        print(f"⚠️ No face detected in {file}")

# cv2.destroyAllWindows()

# 💾 Save embeddings + names
data = {
    'embeddings': np.array(known_embeddings),
    'names': classNames
}
with open('ilhan_v1.pkl', 'wb') as f:
    pickle.dump(data, f)

print("✅ Saved face embeddings to face_data_hb-uzb.pkl")
# Out:
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'sdpa_kernel': '0', 'use_tf32': '1', 'fuse_conv_bias': '0', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# find model: /home/oybek/.insightface/models/buffalo_l/1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# ...

# %% [markdown]
# # Appending pkl

# %%
def append_embedding(new_image_path, pkl_path='hb_korea.pkl'):
    import os
    import cv2
    import pickle
    import numpy as np
    from insightface.app import FaceAnalysis

    # Initialize model
    model = FaceAnalysis(name='buffalo_l')
    model.prepare(ctx_id=0, det_thresh=0.1, det_size=(160, 160))

    # Load existing data
    with open(pkl_path, 'rb') as f:
        data = pickle.load(f)

    embeddings = data['embeddings']
    names = data['names']
    print(name)

    # Load and process image
    img = cv2.imread(new_image_path)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    faces = model.get(img_rgb)

    if faces:
        name = os.path.splitext(os.path.basename(new_image_path))[0]
        if name in names:
            print(f"⚠️ {name} already exists in the dataset. Skipping...")
            return

        emb = faces[0].embedding
        embeddings = np.vstack([embeddings, emb])
        names.append(name)

        # Save updated data
        with open(pkl_path, 'wb') as f:
            pickle.dump({'embeddings': embeddings, 'names': names}, f)

        print(f"✅ Appended embedding for {name} to {pkl_path}")
    else:
        print(f"⚠️ No face detected in {new_image_path}")

append_embedding('Sample_4.jpg', 'hb_korea.pkl')  # Example usage
# Out:
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'sdpa_kernel': '0', 'use_tf32': '1', 'fuse_conv_bias': '0', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# find model: /home/oybek/.insightface/models/buffalo_l/1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# ...

# %% [markdown]
# # Delete embeddings

# %%
def delete_embedding(image_path, pkl_path='hb_korea.pkl'):
    import os
    import pickle
    import numpy as np

    # Extract name from image file
    name_to_delete = os.path.splitext(os.path.basename(image_path))[0]

    # Load existing data
    with open(pkl_path, 'rb') as f:
        data = pickle.load(f)

    embeddings = data['embeddings']
    names = data['names']

    if name_to_delete not in names:
        print(f"❌ {name_to_delete} not found in dataset. Nothing deleted.")
        return

    # Find index and remove
    index = names.index(name_to_delete)
    embeddings = np.delete(embeddings, index, axis=0)
    names.pop(index)

    # Save updated data
    with open(pkl_path, 'wb') as f:
        pickle.dump({'embeddings': embeddings, 'names': names}, f)

    print(f"🗑️ Deleted embedding for {name_to_delete} from {pkl_path}")

delete_embedding('Oybek Inokov_1.jpg', 'hb_korea.pkl')  # Example usage
# Out:
# ❌ Oybek Inokov_1 not found in dataset. Nothing deleted.

# %%
import pandas as pd
import numpy as np

# Path to your .pkl file
pkl_path = "hb_korea.pkl"  # Change this to your actual file path

# Load the pickle file
data = pd.read_pickle(pkl_path)

# Extract embeddings and names
embeddings = data['embeddings']
names = data['names']

# Convert embeddings to DataFrame
df = pd.DataFrame(embeddings)

# Insert names as the first column
df.insert(0, 'name', names)
row, col = df.shape
print(f"DataFrame shape: {row} rows, {col} columns")
# Save the DataFrame to a CSV file
csv_path = "embeddings_converted.csv"  # Output file name
df.to_csv(csv_path, index=False)

print(f"CSV file saved to: {csv_path}")
# Out:
# DataFrame shape: 67 rows, 513 columns
# CSV file saved to: embeddings_converted.csv

# %%
import numpy as np

# Extract data
embeddings = data['embeddings']
names = data['names']

# Convert to DataFrame
df = pd.DataFrame(embeddings)
df.insert(0, 'name', names)  # Insert names as the first column

# Save to CSV
csv_path = "/mnt/data/embeddings_converted.csv"
df.to_csv(csv_path, index=False)

# Display path to user
csv_path
# Out:
#   Cell In[13], line 1
#     def append_embaddings():
#                             ^
# SyntaxError: incomplete input
